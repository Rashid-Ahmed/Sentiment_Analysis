# %%
#!pip install sentence_transformers
#!pip install transformers

import torch
import warnings
from utils.train_transformer import train_model
import os
warnings.filterwarnings('ignore')

# %%
BATCH_SIZE = 16
EPOCHS = 10
STEP_SIZE = 0.00001
MODEL = 'microsoft/deberta-v3-base'
DATA_LEN = 205000
DATA_DIR = 'data'
DATA_FILE_NAME = 'sentiment_data.csv'
CHECKPOINT_DIR = 'checkpoints'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_model(MODEL , DATA_LEN , CHECKPOINT_DIR, device, os.path.join(DATA_DIR, DATA_FILE_NAME) ,EPOCHS, STEP_SIZE, BATCH_SIZE, load_model = True)

# %%
from transformers import AutoModelForSequenceClassification
bert_model = AutoModelForSequenceClassification.from_pretrained(MODEL, num_labels = 3).to(device)
bert_model.load_state_dict(torch.load(os.path.join(CHECKPOINT_DIR, 'model_deberta.ckpt'), map_location=device))
